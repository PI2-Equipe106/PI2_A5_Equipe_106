, 672349.5 6896441.2, 672406.6 6896502.7, 672491.2 6896457, 672689.8 6896367.4, 672843.7 6896235.2, 672926.4 6896121.5, 673069.2 6896113.3, 673257.8 6896086.8, 673449.7 6895860.3, 673668.3 6895567.6, 673813 6895281.5, 673897.6 6894969, 674011.6 6894639.2, 674089 6894504.7, 674117.8 6894315.5, 674346.7 6894046.8, 674550.1 6893768.2, 674726.9 6893602.8, 674908 6893627.3, 675124.7 6893606.5, 675306.7 6893454, 675360.1 6893400.6, 675414.8 6893284.2, 675472.1 6893143.8, 675567.6 6893080, 675767.7 6893044.4, 675826.3 6893039.9, 675902.8 6893019.2, 675886.2 6892973.4, 675830 6892853.9, 675724.2 6892690.9, 675640 6892577.7, 675598 6892454.1, 675580 6892237.4, 675550.6 6892109.7, 675598.9 6891914.4, 675739.1 6891740.4, 675893.2 6891573.2, 675931.4 6891402.9, 675942.8 6891245.9, 675918.5 6891079.2, 675912.1 6890846.4, 675920.9 6890711.4, 675989.6 6890549.9, 676118.4 6890395.9, 676245.7 6890211, 676325.9 6890020.4, 676379.4 6889819.1, 676321.9 6889521.7, 676167.6 6889259.2, 675967.4 6889086, 675847.5 6888959.1, 675759.5 6888771.9, 675760.7 6888536, 675809 6888258.8, 675816.5 6887994.9, 675736.1 6887776.7, 675469.7 6887568.1, 675301.4 6887345.6, 675173.8 6887057.8, 675130.4 6886907.3, 675032.2 6886624.3, 674976 6886302.9, 674922.3 6886031.6, 674867.3 6885675.2, 674812.4 6885314.9, 674730.7 6885020.8, 674703.9 6884920))"
coord_string = str(x)

coord_string = coord_string.replace("POLYGON ((", "").replace("))", "")

# Diviser les paires lon/lat et les séparer en listes distinctes
lon_lat_pairs = [pair.split() for pair in coord_string.split(",")]

# Convertir les paires lon/lat en tuples de float
coordinates = [(float(lon), float(lat)) for lon, lat in lon_lat_pairs]

# Construire la chaîne de caractères du polygone
polygon_string = "Polygon([" + ", ".join([f"({lon}, {lat})" for lon, lat in coordinates]) + "])"

# Afficher la chaîne de caractères du polygone
#print(polygon_string)

coord_string = coord_string.replace("POLYGON ((", "").replace("))", "")

# Diviser les paires lon/lat et les séparer en listes distinctes
lon_lat_pairs = [pair.split() for pair in coord_string.split(",")]

# Convertir les paires lon/lat en tuples de float
coordinates = [(float(lon), float(lat)) for lon, lat in lon_lat_pairs]

# Construire la chaîne de caractères du polygone
polygon_string = "Polygon([" + ", ".join([f"({lon}, {lat})" for lon, lat in coordinates]) + "])"

# Afficher la chaîne de caractères du polygone
#print(polygon_string)


exec(f"y = {polygon_string}")


# Définir les coordonnées du polygone Lambert 93
#polygon_lambert93 = Polygon([(891136.1, 6534658.5),(891133.9, 6534656.1),(891125.3, 6534662.5),(891134, 6534672.8),(891137.3, 6534668.7),(891136.1, 6534658.5)])

polygon_lambert93 = y

# Créer un GeoDataFrame avec le polygone Lambert 93
gdf = gpd.GeoDataFrame(geometry=[polygon_lambert93])

# Définir la projection source (Lambert 93)
src_crs = {'init': 'epsg:2154'}  # EPSG 2154 correspond à Lambert 93
gdf.crs = src_crs  # Définir le CRS pour le GeoDataFrame

# Définir la projection cible (WGS84)
target_crs = {'init': 'epsg:4326'}  # EPSG 4326 correspond à WGS84

# Convertir le GeoDataFrame vers la nouvelle projection
gdf = gdf.to_crs(target_crs)

# Afficher le GeoDataFrame avec les nouvelles coordonnées GPS
#print(gdf)

# Vous pouvez également extraire les coordonnées GPS du polygone
polygon_gps_coords = [(lon, lat) for lon, lat in zip(*gdf.geometry.iloc[0].exterior.xy)]


polygon_gps_coords = [(lon, lat) for lon, lat in zip(*gdf.geometry.iloc[0].exterior.xy)]

# Construire la chaîne de caractères pour le polygone GPS
polygon_gps_str = "POLYGON ((" + ", ".join([f"{lat} {lon}" for lon, lat in polygon_gps_coords]) + "))"

# Afficher la chaîne de caractères du polygone GPS
print(polygon_gps_str)

coord_string = str(polygon_gps_str)

coord_string = coord_string.replace("POLYGON ((", "").replace("))", "")

# Diviser les paires lon/lat et les séparer en listes distinctes
lon_lat_pairs = [pair.split() for pair in coord_string.split(",")]

# Convertir les paires lon/lat en tuples de float
coordinates = [(float(lon), float(lat)) for lon, lat in lon_lat_pairs]

# Construire la chaîne de caractères du polygone
polygon_string = "Polygon([" + ", ".join([f"({lon}, {lat})" for lon, lat in coordinates]) + "])"

# Afficher la chaîne de caractères du polygone
#print(polygon_string)

coord_string = coord_string.replace("POLYGON ((", "").replace("))", "")

# Diviser les paires lon/lat et les séparer en listes distinctes
lon_lat_pairs = [pair.split() for pair in coord_string.split(",")]

# Convertir les paires lon/lat en tuples de float
coordinates = [(float(lon), float(lat)) for lon, lat in lon_lat_pairs]

# Construire la chaîne de caractères du polygone
polygon_string = "Polygon([" + ", ".join([f"({lon}, {lat})" for lon, lat in coordinates]) + "])"

# Afficher la chaîne de caractères du polygone
print(polygon_string)
# Out:
# POLYGON ((49.06364228332447 2.653866527405697, 49.063863036014006 2.652157363878076, 49.06432900918138 2.649137018269709, 49.06502916986376 2.645975446552521, 49.065456578464506 2.643950057638457, 49.06602873167696 2.641628061771594, 49.067007591556404 2.638220761910787, 49.068935891272815 2.636306500878939, 49.070818675656625 2.6342199836645577, 49.07273880675592 2.632009877889237, 49.073222614547376 2.6288148924393773, 49.07264099694719 2.6253798233192382, 49.07252284027066 2.624685441621926, 49.07111561004523 2.61923516411074, 49.06970507100738 2.6156354160305155, 49.06840253380408 2.611545144741261, 49.066486237825956 2.6084367695930215, 49.065762311534336 2.606752264034121, 49.06636598365345 2.606032009196014, 49.06710647764485 2.6042652150337733, 49.068790103875266 2.6027538916636717, 49.07102435520838 2.6005402848310726, 49.07285374089684 2.5979970559062626, 49.07416279420176 2.5952852589623645, 49.07508480363502 2.5924709789927562, 49.07553669131806 2.591298597521239, 49.0758
# ...
